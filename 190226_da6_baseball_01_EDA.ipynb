# %% [markdown]
# # 데이콘 6 야구

# %% [markdown]
# ### 01 데이터 불러오기

# %%
import pandas as pd # 테뷸러 데이터(테이블 데이터 다룰때)
import matplotlib.pyplot as plt
import seaborn as sns
import os # 디렉토리 설정시 필요
import numpy as np # 행렬 연산

# %%
# change dir
os.chdir('C:\\Users\\ktm\\Downloads\\6th_Competition_data')
# os.chdir('C:/Users/ktm/Downloads/6th_Competition_data')

# %%
pwd
# Out:
# 'C:\\Users\\ktm\\Downloads\\6th_Competition_data'

# %%
regular = pd.read_csv('Regular_Season_batter.csv')

# %%
regular.head(6)
# Out:
#    batter_id batter_name  year team    avg    G   AB   R   H  2B  ...    GDP  \
# 0          0        가르시아  2018   LG  0.339   50  183  27  62   9  ...      3
# 1          1         강경학  2011   한화  0.000    2    1   0   0   0  ...      0
# 2          1         강경학  2014   한화  0.221   41   86  11  19   2  ...      1
# 3          1         강경학  2015   한화  0.257  120  311  50  80   7  ...      3
# 4          1         강경학  2016   한화  0.158   46  101  16  16   3  ...      5
# 5          1         강경학  2017   한화  0.214   59   84  17  18   2  ...      1
#
#      SLG    OBP   E  height/weight      year_born   position  \
# 0  0.519  0.383   9     177cm/93kg  1985년 04월 12일  내야수(우투우타)
# 1  0.000  0.000   1     180cm/72kg  1992년 08월 11일  내야수(우투좌타)
# 2  0.349  0.337   6     180cm/72kg  1992년 08월 11일  내야수(우투좌타)
# 3  0.325  0.348  15     180cm/72kg  1992년 08월 11일  내야수(우투좌타)
# 4  0.257  0.232   7     180cm/72kg  1992년 08월 11일  내야수(우투좌타)
# ...

# %%
pd.set_option('display.max_columns', 500)

# %%
regular.head()
# Out:
#    batter_id batter_name  year team    avg    G   AB   R   H  2B  3B  HR   TB  \
# 0          0        가르시아  2018   LG  0.339   50  183  27  62   9   0   8   95
# 1          1         강경학  2011   한화  0.000    2    1   0   0   0   0   0    0
# 2          1         강경학  2014   한화  0.221   41   86  11  19   2   3   1   30
# 3          1         강경학  2015   한화  0.257  120  311  50  80   7   4   2  101
# 4          1         강경학  2016   한화  0.158   46  101  16  16   3   2   1   26
#
#    RBI  SB  CS  BB  HBP  SO  GDP    SLG    OBP   E height/weight  \
# 0   34   5   0   9    8  25    3  0.519  0.383   9    177cm/93kg
# 1    0   0   0   0    0   1    0  0.000  0.000   1    180cm/72kg
# 2    7   0   0  13    2  28    1  0.349  0.337   6    180cm/72kg
# 3   27   4   3  40    5  58    3  0.325  0.348  15    180cm/72kg
# 4    7   0   0   8    2  30    5  0.257  0.232   7    180cm/72kg
#
#        year_born   position                                  career  \
# ...

# %% [markdown]
# * avg : 타율<br>
# * G : 출전 게임수<br>
# * AB : 타수(타자가 타석에 얼마나 섰는지)<br>
# * R : 득점<br>
# * H : 총안타<br>
# * 2B : 2루타 수<br>
# * 3B : 3루타 수<br>
# * HR : 홈런 수<br>
# * TB : 루타 수<br>
# * RBI : 타점 수<br>
# * SB : 도루 성공 횟수<br>
# * CS : 도루 실패 횟수<br>
# * BB : 볼넷 수<br>
# * HBP : 사구<br>
# * SO : 삼진 아웃<br>
# * GDP : 병살타 수<br>
# * SLG : 장타율<br>
# * OBP : 출루율<br>
# * E : 에러 수(수비 실책)<br>
# * position : 수비위치<br>
# * OPS : target

# %%
regular.columns
# Out:
# Index(['batter_id', 'batter_name', 'year', 'team', 'avg', 'G', 'AB', 'R', 'H',
#        '2B', '3B', 'HR', 'TB', 'RBI', 'SB', 'CS', 'BB', 'HBP', 'SO', 'GDP',
#        'SLG', 'OBP', 'E', 'height/weight', 'year_born', 'position', 'career',
#        'starting_salary', 'OPS'],
#       dtype='object')

# %%
regular
# Out:
#       batter_id batter_name  year  team    avg    G   AB   R    H  2B  3B  HR  \
# 0             0        가르시아  2018    LG  0.339   50  183  27   62   9   0   8
# 1             1         강경학  2011    한화  0.000    2    1   0    0   0   0   0
# 2             1         강경학  2014    한화  0.221   41   86  11   19   2   3   1
# 3             1         강경학  2015    한화  0.257  120  311  50   80   7   4   2
# 4             1         강경학  2016    한화  0.158   46  101  16   16   3   2   1
# 5             1         강경학  2017    한화  0.214   59   84  17   18   2   1   0
# 6             1         강경학  2018    한화  0.278   77  245  42   68  11   1   5
# 7             2         강구성  2013    NC  0.000    2    2   0    0   0   0   0
# 8             2         강구성  2015    NC  0.200    4    5   0    1   1   0   0
# 9             2         강구성  2016    NC  0.000    2    3   0    0   0   0   0
# 10            2         강구성  2017    NC  0.000    1    1   0    0   0   0   0
# ...

# %%
regular['avg']
# Out:
# 0       0.339
# 1       0.000
# 2       0.221
# 3       0.257
# 4       0.158
# 5       0.214
# 6       0.278
# 7       0.000
# 8       0.200
# 9       0.000
# 10      0.000
# 11      0.200
# 12      0.127
# 13      0.139
# 14      0.000
# 15      0.000
# 16      0.176
# 17      0.231
# 18        NaN
# 19      0.242
# 20      0.269
# 21      0.212
# 22      0.273
# 23      0.306
# 24      0.281
# 25      0.290
# 26      0.278
# 27      0.288
# 28      0.288
# 29      0.246
#         ...
# 2424    0.000
# 2425    0.181
# 2426    0.200
# 2427    0.222
# 2428    0.125
# 2429    0.174
# 2430    0.000
# 2431    0.083
# 2432    0.133
# 2433    0.158
# 2434    0.300
# 2435    0.239
# 2436    0.284
# 2437    0.225
# 2438    0.289
# 2439    0.272
# 2440    0.274
# 2441    0.321
# 2442    0.290
# 2443    0.335
# 2444    0.296
# 2445    0.149
# 2446    0.244
# 2447    0.111
# 2448      NaN
# 2449    0.000
# 2450    0.000
# 2451    0.000
# 2452    0.291
# 2453    0.167
# ...

# %%
regular['batter_name']
# Out:
# 0       가르시아
# 1        강경학
# 2        강경학
# 3        강경학
# 4        강경학
# 5        강경학
# 6        강경학
# 7        강구성
# 8        강구성
# 9        강구성
# 10       강구성
# 11       강구성
# 12       백승룡
# 13       백승룡
# 14       백승룡
# 15       백승룡
# 16       백승룡
# 17       백승룡
# 18       백승룡
# 19       진갑용
# 20       진갑용
# 21       진갑용
# 22       진갑용
# 23       진갑용
# 24       진갑용
# 25       진갑용
# 26       진갑용
# 27       진갑용
# 28       진갑용
# 29       진갑용
#         ...
# 2424     황선일
# 2425     황선일
# 2426     황선일
# 2427     황선일
# 2428     황선일
# 2429     황선일
# 2430     황윤호
# 2431     황윤호
# 2432     황윤호
# 2433     황윤호
# 2434     황재균
# 2435     황재균
# 2436     황재균
# 2437     황재균
# 2438     황재균
# 2439     황재균
# 2440     황재균
# 2441     황재균
# 2442     황재균
# 2443     황재균
# 2444     황재균
# 2445     황정립
# 2446     황정립
# 2447     황진수
# 2448     황진수
# 2449     황진수
# 2450     황진수
# 2451     황진수
# 2452     황진수
# 2453     황진수
# Name: batter_name, Length: 2454, dtype: object

# %%
regular['batter_name'].iloc[5-1]
# Out:
# '강경학'

# %%
regular['batter_name'].iloc[0]
# Out:
# '가르시아'

# %%
regular[['year', 'team', 'avg']]
# Out:
#       year  team    avg
# 0     2018    LG  0.339
# 1     2011    한화  0.000
# 2     2014    한화  0.221
# 3     2015    한화  0.257
# 4     2016    한화  0.158
# 5     2017    한화  0.214
# 6     2018    한화  0.278
# 7     2013    NC  0.000
# 8     2015    NC  0.200
# 9     2016    NC  0.000
# 10    2017    NC  0.000
# 11    2018    NC  0.200
# 12    2005    한화  0.127
# 13    2006    한화  0.139
# 14    2007    한화  0.000
# 15    2008    한화  0.000
# 16    2011    한화  0.176
# 17    2012    한화  0.231
# 18    2013    한화    NaN
# 19    1997    OB  0.242
# 20    1998    OB  0.269
# 21    1999    삼성  0.212
# 22    2000    삼성  0.273
# 23    2001    삼성  0.306
# 24    2002    삼성  0.281
# 25    2003    삼성  0.290
# 26    2004    삼성  0.278
# 27    2005    삼성  0.288
# 28    2006    삼성  0.288
# 29    2007    삼성  0.246
# ...    ...   ...    ...
# 2424  2006    LG  0.000
# 2425  2007    LG  0.181
# 2426  2010    LG  0.200
# 2427  2011    LG  0.222
# 2428  2012    LG  0.125
# 2429  2015    한화  0.174
# ...

# %%
 regular['2B']
# Out:
# 0        9
# 1        0
# 2        2
# 3        7
# 4        3
# 5        2
# 6       11
# 7        0
# 8        1
# 9        0
# 10       0
# 11       1
# 12       2
# 13       2
# 14       0
# 15       0
# 16       2
# 17       1
# 18       0
# 19       7
# 20      14
# 21       3
# 22      14
# 23      25
# 24      29
# 25      20
# 26      20
# 27      17
# 28      22
# 29      12
#         ..
# 2424     0
# 2425     3
# 2426     1
# 2427     0
# 2428     0
# 2429     2
# 2430     0
# 2431     0
# 2432     0
# 2433     1
# 2434     6
# 2435    10
# 2436    27
# 2437    14
# 2438    18
# 2439    19
# 2440    29
# 2441    33
# 2442    41
# 2443    26
# 2444    41
# 2445     0
# 2446     2
# 2447     1
# 2448     0
# 2449     0
# 2450     0
# 2451     0
# 2452     6
# 2453     1
# Name: 2B, Length: 2454, dtype: int64

# %%
regular['2B'].iloc[3]
# Out:
# 7

# %%
re1=regular[['batter_name', 'year', 'AB', 'position', 'OPS']]

# %%
re1
# Out:
#      batter_name  year   AB   position       OPS
# 0           가르시아  2018  183  내야수(우투우타)  0.902000
# 1            강경학  2011    1  내야수(우투좌타)  0.000000
# 2            강경학  2014   86  내야수(우투좌타)  0.686000
# 3            강경학  2015  311  내야수(우투좌타)  0.673000
# 4            강경학  2016  101  내야수(우투좌타)  0.489000
# 5            강경학  2017   84  내야수(우투좌타)  0.552000
# 6            강경학  2018  245  내야수(우투좌타)  0.774000
# 7            강구성  2013    2  외야수(우투좌타)  0.000000
# 8            강구성  2015    5  외야수(우투좌타)  0.600000
# 9            강구성  2016    3  외야수(우투좌타)  0.000000
# 10           강구성  2017    1  외야수(우투좌타)  0.000000
# 11           강구성  2018    5  외야수(우투좌타)  0.600000
# 12           백승룡  2005   63        NaN  0.415487
# 13           백승룡  2006   36        NaN  0.520531
# 14           백승룡  2007    4        NaN  0.000000
# 15           백승룡  2008    1        NaN  0.000000
# 16           백승룡  2011   51        NaN  0.515686
# 17           백승룡  2012   52        NaN  0.594262
# ...

# %%
re1['batter_name'].nunique()
# Out:
# 345

# %%
sns.distplot(re1['year'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# -> 연도수가 높아질 수록 데이터 빈도가 높다.

# %%
re1['year'].describe() # numeric data에 대한 요약 통계
# Out:
# count    2454.000000
# mean     2011.614507
# std         4.992833
# min      1993.000000
# 25%      2008.000000
# 50%      2013.000000
# 75%      2016.000000
# max      2018.000000
# Name: year, dtype: float64

# %%
sns.distplot(re1['AB'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# -> 100타 미만의 빈도가 높다.

# %%
re1['AB'].describe()
# Out:
# count    2454.000000
# mean      201.514670
# std       169.537029
# min         0.000000
# 25%        38.250000
# 50%       163.000000
# 75%       357.500000
# max       600.000000
# Name: AB, dtype: float64

# %%
# 범주데이터 : categorical data -> value_counts로 빈도수 확인
re1['position'].value_counts()
# Out:
# 내야수(우투우타)    643
# 외야수(우투우타)    230
# 외야수(좌투좌타)    201
# 포수(우투우타)     189
# 외야수(우투좌타)    184
# 내야수(우투좌타)    141
# 내야수(좌투좌타)     36
# 포수(우투좌타)      14
# 내야수(우투양타)      7
# 외야수(우투양타)      7
# Name: position, dtype: int64

# %% [markdown]
# -> 양타자 데이터 수가 적다.

# %%
re1['OPS'].describe() # NAN 값 존재
# Out:
# count    2428.000000
# mean        0.649939
# std         0.261634
# min         0.000000
# 25%         0.546000
# 50%         0.688637
# 75%         0.797234
# max         4.000000
# Name: OPS, dtype: float64

# %%
sns.distplot(re1['OPS'].dropna())
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
re1.head()
# Out:
#   batter_name  year   AB   position    OPS
# 0        가르시아  2018  183  내야수(우투우타)  0.902
# 1         강경학  2011    1  내야수(우투좌타)  0.000
# 2         강경학  2014   86  내야수(우투좌타)  0.686
# 3         강경학  2015  311  내야수(우투좌타)  0.673
# 4         강경학  2016  101  내야수(우투좌타)  0.489

# %%
plt.scatter(re1['AB'], re1['OPS'])

# %%
plt.scatter(re1['AB'], re1['OPS'])
plt.xlabel('AB')
plt.ylabel('OPS')
# Out:
# Text(0,0.5,'OPS')

# %%
plt.scatter(re1['year'], re1['AB'])
plt.xlabel('year')
plt.ylabel('AB')
# Out:
# Text(0,0.5,'AB')

# %%
re1.groupby(['position'])['OPS'].mean()
# Out:
# position
# 내야수(우투양타)    0.275000
# 내야수(우투우타)    0.674866
# 내야수(우투좌타)    0.642086
# 내야수(좌투좌타)    0.748972
# 외야수(우투양타)    0.697714
# 외야수(우투우타)    0.665179
# 외야수(우투좌타)    0.685956
# 외야수(좌투좌타)    0.656005
# 포수(우투우타)     0.613227
# 포수(우투좌타)     0.592643
# Name: OPS, dtype: float64

# %%
re1.groupby(['position'])['AB'].mean()
# Out:
# position
# 내야수(우투양타)     25.142857
# 내야수(우투우타)    229.539658
# 내야수(우투좌타)    183.092199
# 내야수(좌투좌타)    271.027778
# 외야수(우투양타)    169.571429
# 외야수(우투우타)    205.665217
# 외야수(우투좌타)    250.141304
# 외야수(좌투좌타)    259.388060
# 포수(우투우타)     142.417989
# 포수(우투좌타)     120.142857
# Name: AB, dtype: float64

# %%
re1.groupby(['position'])['OPS'].median()
# Out:
# position
# 내야수(우투양타)    0.1625
# 내야수(우투우타)    0.7060
# 내야수(우투좌타)    0.6890
# 내야수(좌투좌타)    0.7955
# 외야수(우투양타)    0.7980
# 외야수(우투우타)    0.7230
# 외야수(우투좌타)    0.7430
# 외야수(좌투좌타)    0.7010
# 포수(우투우타)     0.6400
# 포수(우투좌타)     0.6075
# Name: OPS, dtype: float64

# %%
re1.groupby(['position'])['AB'].max()
# Out:
# position
# 내야수(우투양타)    117
# 내야수(우투우타)    575
# 내야수(우투좌타)    560
# 내야수(좌투좌타)    492
# 외야수(우투양타)    564
# 외야수(우투우타)    576
# 외야수(우투좌타)    576
# 외야수(좌투좌타)    600
# 포수(우투우타)     489
# 포수(우투좌타)     352
# Name: AB, dtype: int64

# %%
re1.groupby(['position'])['AB'].min()
# Out:
# position
# 내야수(우투양타)    0
# 내야수(우투우타)    0
# 내야수(우투좌타)    0
# 내야수(좌투좌타)    1
# 외야수(우투양타)    6
# 외야수(우투우타)    0
# 외야수(우투좌타)    0
# 외야수(좌투좌타)    0
# 포수(우투우타)     0
# 포수(우투좌타)     6
# Name: AB, dtype: int64

# %% [markdown]
# #### groupby : 카테고리별 뉴메릭 데이터를 보고자 할 때
