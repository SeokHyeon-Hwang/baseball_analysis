# %% [markdown]
# # Feature Engenearing

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
from matplotlib import rc, font_manager
rc('font', family='NanumSquareR')
import os

# %%
os.chdir('C:\\Users\\ktm\\0226_0408_study\\dataset\\6th_Competition_data')

# %%
regular = pd.read_csv('Regular_Season_Batter.csv')

# %% [markdown]
# ## 1. 데이터 잘라내기

# %%
regular
# Out:
#       batter_id batter_name  year  team    avg    G   AB   R    H  2B  \
# 0             0        가르시아  2018    LG  0.339   50  183  27   62   9
# 1             1         강경학  2011    한화  0.000    2    1   0    0   0
# 2             1         강경학  2014    한화  0.221   41   86  11   19   2
# 3             1         강경학  2015    한화  0.257  120  311  50   80   7
# 4             1         강경학  2016    한화  0.158   46  101  16   16   3
# 5             1         강경학  2017    한화  0.214   59   84  17   18   2
# 6             1         강경학  2018    한화  0.278   77  245  42   68  11
# 7             2         강구성  2013    NC  0.000    2    2   0    0   0
# 8             2         강구성  2015    NC  0.200    4    5   0    1   1
# 9             2         강구성  2016    NC  0.000    2    3   0    0   0
# 10            2         강구성  2017    NC  0.000    1    1   0    0   0
# 11            2         강구성  2018    NC  0.200    4    5   0    1   1
# ...

# %% [markdown]
# 1. ops가 0.9를 넘는 row
# 2. batter_name이 박석민인 row
# 3. year이 2010보다 큰 row

# %%
regular.loc[regular['OPS']>0.9]
# Out:
#       batter_id batter_name  year team    avg    G   AB    R    H  2B  \
# 0             0        가르시아  2018   LG  0.339   50  183   27   62   9
# 53            4         강민호  2015   롯데  0.311  123  380   63  118  18
# 54            4         강민호  2016   롯데  0.323  116  381   65  123  26
# 78            7         강봉규  2009   삼성  0.310  126  449   89  139  24
# 95           10         강정호  2012   넥센  0.314  124  436   77  137  32
# 97           10         강정호  2014   넥센  0.356  117  418  103  149  36
# 98           11         강진성  2013   NC  0.500    3    2    1    1   1
# 99           11         강진성  2017   NC  0.296   28   27    5    8   3
# 130          17         고영민  2013   두산  0.286   10   14    3    4   1
# 135         230         이종환  2012  KIA  0.385    6   13    2    5   2
# 147          19         구자욱  2015   삼성  0.349  116  410   97  143  33
# 148          19         구자욱  2016   삼성  0.343  108  428  105  147  19
# ...

# %%
regular.loc[regular['batter_name']=='박석민']
# Out:
#      batter_id batter_name  year team    avg    G   AB   R    H  2B  ...    \
# 797        115         박석민  2004   삼성  0.103   23   29   2    3   1  ...
# 798        115         박석민  2005   삼성  0.198   52   81   7   16   3  ...
# 799        115         박석민  2008   삼성  0.279  126  416  65  116  27  ...
# 800        115         박석민  2009   삼성  0.285   97  295  63   84  17  ...
# 801        115         박석민  2010   삼성  0.303  112  356  58  108  18  ...
# 802        115         박석민  2011   삼성  0.278  128  457  74  127  24  ...
# 803        115         박석민  2012   삼성  0.312  127  443  79  138  19  ...
# 804        115         박석민  2013   삼성  0.318  117  396  61  126  24  ...
# 805        115         박석민  2014   삼성  0.315  110  356  77  112  21  ...
# 806        115         박석민  2015   삼성  0.321  135  448  90  144  25  ...
# 807        115         박석민  2016   NC  0.307  126  427  77  131  20  ...
# 808        115         박석민  2017   NC  0.245  101  319  43   78  15  ...
# ...

# %%
regular.loc[regular['year']>2010]
# Out:
#       batter_id batter_name  year team    avg    G   AB   R    H  2B  \
# 0             0        가르시아  2018   LG  0.339   50  183  27   62   9
# 1             1         강경학  2011   한화  0.000    2    1   0    0   0
# 2             1         강경학  2014   한화  0.221   41   86  11   19   2
# 3             1         강경학  2015   한화  0.257  120  311  50   80   7
# 4             1         강경학  2016   한화  0.158   46  101  16   16   3
# 5             1         강경학  2017   한화  0.214   59   84  17   18   2
# 6             1         강경학  2018   한화  0.278   77  245  42   68  11
# 7             2         강구성  2013   NC  0.000    2    2   0    0   0
# 8             2         강구성  2015   NC  0.200    4    5   0    1   1
# 9             2         강구성  2016   NC  0.000    2    3   0    0   0
# 10            2         강구성  2017   NC  0.000    1    1   0    0   0
# 11            2         강구성  2018   NC  0.200    4    5   0    1   1
# 16          138         백승룡  2011   한화  0.176   38   51   7    9   2
# ...

# %% [markdown]
# 4. 박석민 선수의 역대 OPS를 알고자 할 때

# %%
batter_park=regular.loc[regular['batter_name']=='박석민']
batter_park
# Out:
#      batter_id batter_name  year team    avg    G   AB   R    H  2B  ...    \
# 797        115         박석민  2004   삼성  0.103   23   29   2    3   1  ...
# 798        115         박석민  2005   삼성  0.198   52   81   7   16   3  ...
# 799        115         박석민  2008   삼성  0.279  126  416  65  116  27  ...
# 800        115         박석민  2009   삼성  0.285   97  295  63   84  17  ...
# 801        115         박석민  2010   삼성  0.303  112  356  58  108  18  ...
# 802        115         박석민  2011   삼성  0.278  128  457  74  127  24  ...
# 803        115         박석민  2012   삼성  0.312  127  443  79  138  19  ...
# 804        115         박석민  2013   삼성  0.318  117  396  61  126  24  ...
# 805        115         박석민  2014   삼성  0.315  110  356  77  112  21  ...
# 806        115         박석민  2015   삼성  0.321  135  448  90  144  25  ...
# 807        115         박석민  2016   NC  0.307  126  427  77  131  20  ...
# 808        115         박석민  2017   NC  0.245  101  319  43   78  15  ...
# ...

# %%
batter_park['OPS']
# Out:
# 797    0.429
# 798    0.542
# 799    0.835
# 800    1.002
# 801    0.920
# 802    0.816
# 803    0.957
# 804    0.940
# 805    1.020
# 806    0.992
# 807    0.982
# 808    0.792
# 809    0.816
# Name: OPS, dtype: float64

# %%
batter_park[['year', 'OPS']]
# Out:
#      year    OPS
# 797  2004  0.429
# 798  2005  0.542
# 799  2008  0.835
# 800  2009  1.002
# 801  2010  0.920
# 802  2011  0.816
# 803  2012  0.957
# 804  2013  0.940
# 805  2014  1.020
# 806  2015  0.992
# 807  2016  0.982
# 808  2017  0.792
# 809  2018  0.816

# %%
batter_park['OPS'].mean()
# Out:
# 0.8494615384615384

# %% [markdown]
# 5. 이름이 박석민이며 year이 2009인 row 뽑아내기

# %%
regular.loc[(regular['batter_name']=='박석민')&(regular['year']==2009)]
# Out:
#      batter_id batter_name  year team    avg   G   AB   R   H  2B  ...    GDP  \
# 800        115         박석민  2009   삼성  0.285  97  295  63  84  17  ...      5
#
#        SLG    OBP  E  height/weight      year_born   position  \
# 800  0.586  0.416  6     178cm/88kg  1985년 06월 22일  내야수(우투우타)
#
#                    career  starting_salary    OPS
# 800  율하초-경복중-대구고-삼성-상무-삼성          18000만원  1.002
#
# [1 rows x 29 columns]

# %% [markdown]
# ## 2. For 문

# %%
'박석민', '채태인', '최형우', '박해민'

# %%
regular.loc[regular['batter_name']=='박석민']['OPS'].mean()
# Out:
# 0.8494615384615384

# %%
for i in ['박석민', '채태인', '최형우', '박해민']:
    print(regular.loc[regular['batter_name']==i]['OPS'].mean())
# Out:
# 0.8494615384615384
# 0.7950833333333335
# 0.9003076923076923
# 0.7525999999999999

# %%
for i in [0,1,2,3]:
    print(regular['OPS'].iloc[i])
# Out:
# 0.902
# 0.0
# 0.6859999999999999
# 0.6729999999999999

# %%
len(regular)
# Out:
# 2454

# %%
for i in range(len(regular)):
    print(regular['OPS'].iloc[i])
# Out:
# 0.902
# 0.0
# 0.6859999999999999
# 0.6729999999999999
# 0.489
# 0.552
# 0.774
# 0.0
# 0.6000000000000001
# 0.0
# 0.0
# 0.6000000000000001
# 0.41548691548691546
# 0.5205314009661836
# 0.0
# 0.0
# 0.5156862745098039
# 0.5942622950819672
# nan
# 0.6157974660067002
# 0.6628473301653566
# 0.5755494505494505
# 0.7380967135568363
# 0.8312472226336839
# 0.8156615074423293
# 0.8472435300021507
# 0.8338632787732194
# 0.7573354363672546
# 0.7489311367004903
# 0.6673319411033862
# 0.7796059017666472
# 0.653967281952585
# 0.7850834027304616
# 0.7601225934559268
# 0.7746134374911122
# 0.7532228360957642
# 0.8235294117647058
# 0.8464052287581699
# 0.0
# 0.0
# 0.504
# 0.5
# 0.0
# 0.6080000000000001
# 0.6729999999999999
# 0.7559999999999999
# 0.85
# 0.758
# 0.9
# 0.846
# 0.823
# 0.742
# 0.767
# 1.06
# 0.982
# 0.843
# 0.7879999999999999
# 0.88
# 0.6693376068376069
# 0.5435897435897437
# 0.5352941176470588
# 0.7579064128359903
# 0.7092731829573935
# 0.7304304304304304
# 0.7972689075630253
# ...

# %%
for i in range(len(regular)):
    print(regular['OPS'].iloc[i]-regular['avg'].iloc[i])
# Out:
# 0.5630000000000001
# 0.0
# 0.46499999999999997
# 0.4159999999999999
# 0.33099999999999996
# 0.3380000000000001
# 0.496
# 0.0
# 0.4000000000000001
# 0.0
# 0.0
# 0.4000000000000001
# 0.28848691548691546
# 0.38153140096618354
# 0.0
# 0.0
# 0.3396862745098038
# 0.36326229508196717
# nan
# 0.37379746600670016
# 0.3938473301653566
# 0.36354945054945054
# 0.46509671355683624
# 0.525247222633684
# 0.5346615074423293
# 0.5572435300021508
# 0.5558632787732194
# 0.4693354363672546
# 0.46093113670049024
# 0.42133194110338623
# 0.5006059017666473
# 0.42196728195258504
# 0.5220834027304616
# 0.4871225934559268
# 0.4676134374911122
# 0.4822228360957642
# 0.4115294117647058
# 0.52240522875817
# 0.0
# 0.0
# 0.374
# 0.25
# 0.0
# 0.3650000000000001
# 0.42199999999999993
# 0.4849999999999999
# 0.558
# 0.498
# 0.595
# 0.5569999999999999
# 0.5499999999999999
# 0.507
# 0.538
# 0.7490000000000001
# 0.659
# 0.558
# 0.5189999999999999
# 0.5900000000000001
# 0.4613376068376069
# 0.40558974358974365
# ...
