# %% [markdown]
# # dacon6 Feature engineering

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')
import warnings
warnings.filterwarnings('ignore')
# %matplotlib.inline
from matplotlib import rc, font_manager
rc('font', family='NanumSquareR')
import os
# Out:
# UsageError: Line magic function `%matplotlib.inline` not found.

# %%
#os.chdir('C:\\Users\\ktm\\Documents\\work\\datasets')

# %%
regular = pd.read_csv('Regular_Season_Batter.csv')

# %%
regular.iloc[4]
# Out:
# batter_id                          1
# batter_name                      강경학
# year                            2016
# team                              한화
# avg                            0.158
# G                                 46
# AB                               101
# R                                 16
# H                                 16
# 2B                                 3
# 3B                                 2
# HR                                 1
# TB                                26
# RBI                                7
# SB                                 0
# CS                                 0
# BB                                 8
# HBP                                2
# SO                                30
# GDP                                5
# SLG                            0.257
# OBP                            0.232
# E                                  7
# height/weight             180cm/72kg
# year_born              1992년 08월 11일
# position                   내야수(우투좌타)
# career             광주대성초-광주동성중-광주동성고
# starting_salary              10000만원
# OPS                            0.489
# Name: 4, dtype: object

# %%
regular.loc[(regular['batter_name']=='강경학')]
# Out:
#    batter_id batter_name  year team    avg    G   AB   R   H  2B  ...    GDP  \
# 1          1         강경학  2011   한화  0.000    2    1   0   0   0  ...      0
# 2          1         강경학  2014   한화  0.221   41   86  11  19   2  ...      1
# 3          1         강경학  2015   한화  0.257  120  311  50  80   7  ...      3
# 4          1         강경학  2016   한화  0.158   46  101  16  16   3  ...      5
# 5          1         강경학  2017   한화  0.214   59   84  17  18   2  ...      1
# 6          1         강경학  2018   한화  0.278   77  245  42  68  11  ...      7
#
#      SLG    OBP   E  height/weight      year_born   position  \
# 1  0.000  0.000   1     180cm/72kg  1992년 08월 11일  내야수(우투좌타)
# 2  0.349  0.337   6     180cm/72kg  1992년 08월 11일  내야수(우투좌타)
# 3  0.325  0.348  15     180cm/72kg  1992년 08월 11일  내야수(우투좌타)
# 4  0.257  0.232   7     180cm/72kg  1992년 08월 11일  내야수(우투좌타)
# 5  0.262  0.290   4     180cm/72kg  1992년 08월 11일  내야수(우투좌타)
# 6  0.392  0.382   2     180cm/72kg  1992년 08월 11일  내야수(우투좌타)
#
#               career  starting_salary    OPS
# 1  광주대성초-광주동성중-광주동성고          10000만원  0.000
# 2  광주대성초-광주동성중-광주동성고          10000만원  0.686
# 3  광주대성초-광주동성중-광주동성고          10000만원  0.673
# 4  광주대성초-광주동성중-광주동성고          10000만원  0.489
# 5  광주대성초-광주동성중-광주동성고          10000만원  0.552
# 6  광주대성초-광주동성중-광주동성고          10000만원  0.774
#
# [6 rows x 29 columns]

# %%
regular.loc[(regular['batter_name']=='강경학')&(regular['year']==2016-1)]
# Out:
#    batter_id batter_name  year team    avg    G   AB   R   H  2B  ...    GDP  \
# 3          1         강경학  2015   한화  0.257  120  311  50  80   7  ...      3
#
#      SLG    OBP   E  height/weight      year_born   position  \
# 3  0.325  0.348  15     180cm/72kg  1992년 08월 11일  내야수(우투좌타)
#
#               career  starting_salary    OPS
# 3  광주대성초-광주동성중-광주동성고          10000만원  0.673
#
# [1 rows x 29 columns]

# %%
regular.loc[(regular['batter_name']=='강경학')&(regular['year']==2016-1)]['OPS']
# 시리즈 형태의 출력
# Out:
# 3    0.673
# Name: OPS, dtype: float64

# %%
regular.loc[(regular['batter_name']=='강경학')&(regular['year']==2016-1)]['OPS'].iloc[0]
# Out:
# 0.6729999999999999

# %%
regular.loc[(regular['batter_name']==regular['batter_name'].iloc[4])&(regular['year']==regular['year'].iloc[4]-1)]['OPS'].iloc[0]
# Out:
# 0.6729999999999999

# %%
# 가르시아는 2018에만 출전하여 데이터 값이 0이라 if문을 써줘야 함.
for i in range(len(regular)):
  regular.loc[(regular['batter_name']==regular['batter_name'].iloc[i])&(regular['year']==regular['year'].iloc[i]-1)]['OPS'].iloc[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-25-ccf01ea5c917> in <module>()
#       1 for i in range(len(regular)):
# ----> 2   regular.loc[(regular['batter_name']==regular['batter_name'].iloc[i])&(regular['year']==regular['year'].iloc[i]-1)]['OPS'].iloc[0]
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1371
#    1372             maybe_callable = com._apply_if_callable(key, self.obj)
# -> 1373             return self._getitem_axis(maybe_callable, axis=axis)
#    1374
#    1375     def _is_scalar_access(self, key):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1828
#    1829             # validate the location
# -> 1830             self._is_valid_integer(key, axis)
#    1831
#    1832             return self._get_loc(key, axis=axis)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in _is_valid_integer(self, key, axis)
#    1711         l = len(ax)
#    1712         if key >= l or key < -l:
# -> 1713             raise IndexError("single positional indexer is out-of-bounds")
#    1714         return True
#    1715
#
# IndexError: single positional indexer is out-of-bounds

# %%
for i in range(len(regular)):
  if len(regular.loc[(regular['batter_name']==regular['batter_name'].iloc[i])&(regular['year']==regular['year'].iloc[i]-1)]['OPS'])==0:
    print(np.nan)
  else:
    print(regular.loc[(regular['batter_name']==regular['batter_name'].iloc[i])&(regular['year']==regular['year'].iloc[i]-1)]['OPS'].iloc[0])

# %%
res=[]

# %%
res.append(1)
res
# Out:
# [1, 1]

# %%
lag_1_OPS=[]
for i in range(len(regular)):
  if len(regular.loc[(regular['batter_name']==regular['batter_name'].iloc[i])&(regular['year']==regular['year'].iloc[i]-1)]['OPS'])==0:
    lag_1_OPS.append(np.nan)
  else:
    lag_1_OPS.append(regular.loc[(regular['batter_name']==regular['batter_name'].iloc[i])&(regular['year']==regular['year'].iloc[i]-1)]['OPS'].iloc[0])
    
print(lag_1_OPS)

# %%
lag_1_OPS

# %%
regular['lag_1_OPS']=lag_1_OPS

# %%
regular.head()
# Out:
#    batter_id batter_name  year team    avg    G   AB   R   H  2B    ...      \
# 0          0        가르시아  2018   LG  0.339   50  183  27  62   9    ...
# 1          1         강경학  2011   한화  0.000    2    1   0   0   0    ...
# 2          1         강경학  2014   한화  0.221   41   86  11  19   2    ...
# 3          1         강경학  2015   한화  0.257  120  311  50  80   7    ...
# 4          1         강경학  2016   한화  0.158   46  101  16  16   3    ...
#
#      SLG    OBP   E  height/weight      year_born   position  \
# 0  0.519  0.383   9     177cm/93kg  1985년 04월 12일  내야수(우투우타)
# 1  0.000  0.000   1     180cm/72kg  1992년 08월 11일  내야수(우투좌타)
# 2  0.349  0.337   6     180cm/72kg  1992년 08월 11일  내야수(우투좌타)
# 3  0.325  0.348  15     180cm/72kg  1992년 08월 11일  내야수(우투좌타)
# 4  0.257  0.232   7     180cm/72kg  1992년 08월 11일  내야수(우투좌타)
#
#                                    career  starting_salary    OPS  lag_1_OPS
# 0  쿠바 Ciego de Avila Maximo Gomez Baez(대)              NaN  0.902        NaN
# 1                       광주대성초-광주동성중-광주동성고          10000만원  0.000        NaN
# 2                       광주대성초-광주동성중-광주동성고          10000만원  0.686        NaN
# 3                       광주대성초-광주동성중-광주동성고          10000만원  0.673      0.686
# 4                       광주대성초-광주동성중-광주동성고          10000만원  0.489      0.673
#
# [5 rows x 30 columns]

# %%
lag_1_avg = []
for i in range(len(regular)):
  if len(regular.loc[(regular['batter_name']==regular['batter_name'].iloc[i])&(regular['year']==regular['year'].iloc[i]-1)]['avg'])==0:
    lag_1_avg.append(np.nan)
  else:
    lag_1_avg.append(regular.loc[(regular['batter_name']==regular['batter_name'].iloc[i])&(regular['year']==regular['year'].iloc[i]-1)]['avg'].iloc[0])
    
lag_1_avg

# %%
regular['lag_1_avg']=lag_1_avg

# %%
regular.columns
# Out:
# Index(['batter_id', 'batter_name', 'year', 'team', 'avg', 'G', 'AB', 'R', 'H',
#        '2B', '3B', 'HR', 'TB', 'RBI', 'SB', 'CS', 'BB', 'HBP', 'SO', 'GDP',
#        'SLG', 'OBP', 'E', 'height/weight', 'year_born', 'position', 'career',
#        'starting_salary', 'OPS', 'lag_1_OPS', 'lag_1_avg'],
#       dtype='object')

# %%
for j in ['avg', 'G', 'AB', 'R', 'H','2B', '3B', 'HR', 'TB', 'RBI', 'SB', 'CS', 'BB', 'HBP', 'SO', 'GDP',
       'SLG', 'OBP', 'E']:
  lag_1_avg=[]
  for i in range(len(regular)):
    if len(regular.loc[(regular['batter_name']==regular['batter_name'].iloc[i])&(regular['year']==regular['year'].iloc[i]-1)][j])==0:
      lag_1_avg.append(np.nan)
    else:
      lag_1_avg.append(regular.loc[(regular['batter_name']==regular['batter_name'].iloc[i])&(regular['year']==regular['year'].iloc[i]-1)][j].iloc[0])
      
  regular['lag_1_'+j]=lag_1_avg
  print(j)
# Out:
# avg
# G
# AB
# R
# H
# 2B
# 3B
# HR
# TB
# RBI
# SB
# CS
# BB
# HBP
# SO
# GDP
# SLG
# OBP
# E

# %%
for j in ['avg', 'G', 'AB', 'R', 'H', '2B', '3B', 'HR', 'TB', 'RBI', 'SB', 'CS', 'BB', 'HBP', 'SO', 'GDP', 'SLG', 'OBP', 'E']:
  lag_2_avg=[]
  for i in range(len(regular)):
    if len(regular.loc[(regular['batter_name']==regular['batter_name'].iloc[i])&(regular['year']==regular['year'].iloc[i]-2)][j])==0:
      lag_2_avg.append(np.nan)
    else:
      lag_2_avg.append(regular.loc[(regular['batter_name']==regular['batter_name'].iloc[i])&(regular['year']==regular['year'].iloc[i]-2)][j].iloc[0])
      
  regular['lag_2_'+j]=lag_2_avg
  print(j)
# Out:
# avg
# G
# AB
# R
# H
# 2B
# 3B
# HR
# TB
# RBI
# SB
# CS
# BB
# HBP
# SO
# GDP
# SLG
# OBP
# E

# %% [markdown]
# # Modeling

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
regular.columns
# Out:
# Index(['batter_id', 'batter_name', 'year', 'team', 'avg', 'G', 'AB', 'R', 'H',
#        '2B', '3B', 'HR', 'TB', 'RBI', 'SB', 'CS', 'BB', 'HBP', 'SO', 'GDP',
#        'SLG', 'OBP', 'E', 'height/weight', 'year_born', 'position', 'career',
#        'starting_salary', 'OPS', 'lag_1_OPS', 'lag_1_avg', 'lag_1_G',
#        'lag_1_AB', 'lag_1_R', 'lag_1_H', 'lag_1_2B', 'lag_1_3B', 'lag_1_HR',
#        'lag_1_TB', 'lag_1_RBI', 'lag_1_SB', 'lag_1_CS', 'lag_1_BB',
#        'lag_1_HBP', 'lag_1_SO', 'lag_1_GDP', 'lag_1_SLG', 'lag_1_OBP',
#        'lag_1_E', 'lag_2_avg', 'lag_2_G', 'lag_2_AB', 'lag_2_R', 'lag_2_H',
#        'lag_2_2B', 'lag_2_3B', 'lag_2_HR', 'lag_2_TB', 'lag_2_RBI', 'lag_2_SB',
#        'lag_2_CS', 'lag_2_BB', 'lag_2_HBP', 'lag_2_SO', 'lag_2_GDP',
#        'lag_2_SLG', 'lag_2_OBP', 'lag_2_E'],
#       dtype='object')

# %%
y=regular['OPS']
X=regular[['lag_1_OPS', 'lag_1_avg', 'lag_1_G',
       'lag_1_AB', 'lag_1_R', 'lag_1_H', 'lag_1_2B', 'lag_1_3B', 'lag_1_HR',
       'lag_1_TB', 'lag_1_RBI', 'lag_1_SB', 'lag_1_CS', 'lag_1_BB',
       'lag_1_HBP', 'lag_1_SO', 'lag_1_GDP', 'lag_1_SLG', 'lag_1_OBP',
       'lag_1_E']]

# %%
print(y.isna())
print(y.head(20))
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18       True
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 2424    False
# 2425    False
# 2426    False
# 2427    False
# 2428    False
# 2429    False
# 2430    False
# 2431    False
# 2432    False
# 2433    False
# 2434    False
# 2435    False
# 2436    False
# 2437    False
# 2438    False
# 2439    False
# 2440    False
# 2441    False
# 2442    False
# 2443    False
# 2444    False
# 2445    False
# 2446    False
# 2447    False
# 2448     True
# 2449    False
# 2450    False
# 2451    False
# 2452    False
# 2453    False
# Name: OPS, Length: 2454, dtype: bool
# 0     0.902000
# 1     0.000000
# 2     0.686000
# 3     0.673000
# 4     0.489000
# 5     0.552000
# 6     0.774000
# 7     0.000000
# 8     0.600000
# 9     0.000000
# 10    0.000000
# 11    0.600000
# 12    0.415487
# 13    0.520531
# 14    0.000000
# 15    0.000000
# 16    0.515686
# 17    0.594262
# 18         NaN
# 19    0.615797
# Name: OPS, dtype: float64

# %% [markdown]
# ### 모델 정의

# %%
rf = RandomForestRegressor(n_estimators=500)

# %%
rf.fit(X.fillna(-1), y.fillna(-1))
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=500, n_jobs=None,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
### 예측
#rf.predict

# %% [markdown]
# ### 모델 성능 평가

# %%
# neuralnet 은 데이터셋이 작으면 좋은 모델을 만들지 못함
# lightgbm 은 na 값을 -1로 채울 필요가 없다.
# randomForest 은 na 값이 없어야 한다.

# %%
# wrmse : weight rmse

# %% [markdown]
# ### 2017년 이전으로 해서 데이터셋 만들기

# %%
train=regular.loc[regular['year']<=2017,]
test=regular.loc[regular['year']==2018,]

X_train = train[['lag_1_OPS', 'lag_1_avg', 'lag_1_G',
       'lag_1_AB', 'lag_1_R', 'lag_1_H', 'lag_1_2B', 'lag_1_3B', 'lag_1_HR',
       'lag_1_TB', 'lag_1_RBI', 'lag_1_SB', 'lag_1_CS', 'lag_1_BB',
       'lag_1_HBP', 'lag_1_SO', 'lag_1_GDP', 'lag_1_SLG', 'lag_1_OBP',
       'lag_1_E']]
y_train = train['OPS']

X_test = test[['lag_1_OPS', 'lag_1_avg', 'lag_1_G',
       'lag_1_AB', 'lag_1_R', 'lag_1_H', 'lag_1_2B', 'lag_1_3B', 'lag_1_HR',
       'lag_1_TB', 'lag_1_RBI', 'lag_1_SB', 'lag_1_CS', 'lag_1_BB',
       'lag_1_HBP', 'lag_1_SO', 'lag_1_GDP', 'lag_1_SLG', 'lag_1_OBP',
       'lag_1_E']]
y_test = test['OPS']

# %%
rf = RandomForestRegressor(n_estimators=500)
rf.fit(X_train.fillna(-1), y_train.fillna(-1))
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=500, n_jobs=None,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
pred = rf.predict(X_test.fillna(-1))

# %%
real = y_test.fillna(-1)

# %%
ab=test['AB']

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(real, pred)
# Out:
# 0.06329960536608831

# %%
# MSE가 아닌 RMSE 이므로 루트 2 (**0.5) 취해준다.
mean_squared_error(real, pred)**0.5
# Out:
# 0.25159412824246974

# %%
# weight rmse 이므로
mean_squared_error(real, pred, sample_weight=ab)**0.5
# Out:
# 0.17144106776512721

# %%
# 타석수에 따른 가중치를 줘야 한다.

rf = RandomForestRegressor(n_estimators=500)
rf.fit(X_train.fillna(-1), y_train.fillna(-1), sample_weight=train['AB'])
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=500, n_jobs=None,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
pred = rf.predict(X_test.fillna(-1))

# %%
real = y_test.fillna(-1)
ab=test['AB']

# %%
mean_squared_error(real, pred, sample_weight=ab)**0.5
# Out:
# 0.1365191108347274
